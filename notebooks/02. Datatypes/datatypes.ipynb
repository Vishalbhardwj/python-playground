# %%
# Int
print(100000)
print(100)
print(0)
print(-10)
print(-1221897398)
print(type(12312))
print('----------------------------')
# Out:
# 100000
# 100
# 0
# -10
# -1221897398
# <class 'int'>
# ----------------------------

# %%
# Float
print(100000.5)
print(100.4)
print(0.0)
print(-10.3)
print(-1221897398.5)
print(type(0.0))
print('----------------------------')
# Out:
# 100000.5
# 100.4
# 0.0
# -10.3
# -1221897398.5
# <class 'float'>
# ----------------------------

# %%
# String
print('A')
print('a')
print('Ashish')
print('Ashish Jangra')
print('This is a class by GFG')
print('sdhskjaf hsjkdahfkjsdhfjk hsdkjf h. sdf sdkjfh kjsd')
print(type("This is Ashish's pen"))
print('----------------------------')
# Out:
# A
# a
# Ashish
# Ashish Jangra
# This is a class by GFG
# sdhskjaf hsjkdahfkjsdhfjk hsdkjf h. sdf sdkjfh kjsd
# <class 'str'>
# ----------------------------

# %%
# Boolean
print(True)
print(False)
print(type('true'))
print(type('True'))
print(type(True))
print('----------------------------')
# Out:
# True
# False
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# ----------------------------

# %% [markdown]
# Functionalities in print statement

# %%
print('a')
print('b')
print('c')
print('a' , 'b', 'c')
print('----------------------------')
# Out:
# a
# b
# c
# a b c
# ----------------------------

# %%
print('a', end = '-')
print('b', end = '-')
print('c')
print('a', 'b','c', end = '*')
print()
print('----------------------------')
# Out:
# a-b-c
# a b c*
# ----------------------------

# %%
print('a','b','c', sep = '_____')
# Out:
# a_____b_____c

# %% [markdown]
# # Python Iterators vs Iterables

# %%
lst = [2, 3, 5, 1, 8, 4 , 9, 77, 56]

for i in lst:
    print(i)
# Out:
# 2
# 3
# 5
# 1
# 8
# 4
# 9
# 77
# 56

# %%
val = iter(lst)

# %%
next(val)
# Out:
# 3

# %%
for i in lst:
    print(i)
# Out:
# 2
# 3
# 5
# 1
# 8
# 4
# 9
# 77
# 56

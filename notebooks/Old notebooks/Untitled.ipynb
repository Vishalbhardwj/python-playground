# %%
print("hkjaldflkfladj")
# Out:
# hkjaldflkfladj

# %%
a = 11393490
b =1934892
print(a+b)
# Out:
# 13328382

# %% [markdown]
# ## ajldjfladjfklaf

# %%
# Hello this is checking file

# %%
print("lajdlfjaldkfjafjl")
# Out:
# lajdlfjaldkfjafjl

# %%
print("lakdjlakjdflfklkldflkadjflkdjflakd")
# Out:
# lakdjlakjdflfklkldflkadjflkdjflakd

# %%
print("klakdjflkdfjs")
# Out:
# klakdjflkdfjs

# %%
'kjaldkjflakdfjaldkf'*100
# Out:
# '...'

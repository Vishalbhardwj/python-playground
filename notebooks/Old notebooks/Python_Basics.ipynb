# %% [markdown]
# # Basics of Python.
# ### Learning python
# * Various Datatypes in Python
# * Variable
# * Variables Assigment
# * Print Formatting

# %% [markdown]
# ## Various Datatypes in python

# %%
1+89
# Out:
# 90

# %%
78-45
# Out:
# 33

# %%
2056-34
# Out:
# 2022

# %%
3*4
# Out:
# 12

# %%
47/4
# Out:
# 11.75

# %%
4**3
# Out:
# 64

# %%
"str"*3
# Out:
# 'strstrstr'

# %%
type("vishal")
# Out:
# str

# %%
type(23.34)
# Out:
# float

# %%
type(45)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
a = "lkdjflajd"
print(a)
# Out:
# lkdjflajd

# %%
b = 10
print(a*b)
# Out:
# lkdjflajdlkdjflajdlkdjflajdlkdjflajdlkdjflajdlkdjflajdlkdjflajdlkdjflajdlkdjflajdlkdjflajd

# %%
c=23.5
print(c)
# Out:
# 23.5

# %%
a = 10
b = 20  
print(a*b)
print(b/a)
print(a%b)
print(b%a)
print((a*b)+(a/b))
# Out:
# 200
# 2.0
# 10
# 0
# 200.5

# %%
print("Hello")
# Out:
# Hello

# %%
first_name = "vishal"
second_name = "bhardwaj"

# %%
print("My first name is {} and last name is {}".format(first_name,second_name))
# Out:
# My first name is vishal and last name is bhardwaj

# %%
print("My first name is {a} and last name is {b}".format(a = second_name, b = first_name))
# Out:
# My first name is bhardwaj and last name is vishal

# %%
len("fklajdf")
# Out:
# 7

# %%
type([23,"str",6])
# Out:
# list

# %%
lst = [ 5 , "keshav", 34.5 , 'rushil']

# %%
print(lst)
# Out:
# [5, 'keshav', 34.5, 'rushil']

# %%
for x in lst:
    print(x)
# Out:
# 5
# keshav
# 34.5
# rushil

# %%
first_str = "This Is The Game12"

# %%
print(first_str)
# Out:
# This Is The Game12

# %%
first_str.replace(" ","").isalnum()
# Out:
# True

# %%
print(first_str)
# Out:
# This Is The Game12

# %%
first_str.lower()
# Out:
# 'this is the game12'

# %%
first_str.islower()
# Out:
# False

# %%
str = "vishal"
str_2 = "bhardwaj34"
print(str+str_2)
# Out:
# vishalbhardwaj34

# %%
str.isalpha() and str_2.isalpha()
# Out:
# False

# %%
print(str_2)  # Above showing false because str_2 contains numeric value
# Out:
# bhardwaj34

# %%
type([])
# Out:
# list

# %%
lst = ['harry' , 45, 'vishal', 422.4, 34,21,'yyouth']

# %%
for x in lst:
    print(x)
# Out:
# harry
# 45
# vishal
# 422.4
# 34
# 21
# yyouth

# %%
type(lst)
# Out:
# list

# %%
len(lst)
# Out:
# 7

# %%
lst.append('jhon')

# %%
for x in lst:
    print(x)
# Out:
# harry
# 45
# vishal
# 422.4
# 34
# 21
# yyouth
# jhon

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 422.4, 34, 21, 'yyouth', 'jhon']

# %%
lst[3:6]
# Out:
# [422.4, 34, 21]

# %%
lst[3:]
# Out:
# [422.4, 34, 21, 'yyouth', 'jhon']

# %%
lst.append(['akd',6])

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 422.4, 34, 21, 'yyouth', 'jhon', ['akd', 6]]

# %%
lst.insert(3,'akldjlfjdf')

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 'akldjlfjdf', 422.4, 34, 21, 'yyouth', 'jhon', ['akd', 6]]

# %%
lst.extend([4,"tiger"])

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 'akldjlfjdf', 422.4, 34, 21, 'yyouth', 'jhon', ['akd', 6], 4, 'tiger']

# %%
lst*8
# Out:
# ['harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
#  'jhon',
#  ['akd', 6],
#  4,
#  'tiger',
#  'harry',
#  45,
#  'vishal',
#  'akldjlfjdf',
#  422.4,
#  34,
#  21,
#  'yyouth',
# ...

# %%
lst_2 = [3, 4, 5, 12, 89,293 ,34,12,7,3,9,12]

# %%
sum(lst_2)
# Out:
# 406

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 'akldjlfjdf', 422.4, 34, 21, 'yyouth', 'jhon', ['akd', 6], 4, 'tiger']

# %%
lst.pop()
# Out:
# 'tiger'

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 'akldjlfjdf', 422.4, 34, 21, 'yyouth', 'jhon', ['akd', 6], 4]

# %%
lst.pop(4)
# Out:
# 422.4

# %%
print(lst)
# Out:
# ['harry', 45, 'vishal', 'akldjlfjdf', 34, 21, 'yyouth', 'jhon', ['akd', 6], 4]

# %%
print(min(lst_2))
# Out:
# 3

# %%
print(max(lst_2))
# Out:
# 293

# %%
lst_2.index(12,1,len(lst_2))
# Out:
# 3

# %%
set_ex = {2, 3, 4, 5, 8}

# %%
print(set_ex)
# Out:
# {2, 3, 4, 5, 8}

# %%
type(set_ex)
# Out:
# set

# %%
set_ex_2 = set()
set_ex_2.add("hulk")

# %%
print(set_ex_2)
# Out:
# {'hulk'}

# %%
set1 = {'tiger', 'lion', 'gang'}
set2 = {'tiger', 'lion', 'gang', 'rahul'}
print(set2)
# Out:
# {'lion', 'gang', 'tiger', 'rahul'}

# %%
set1.intersection(set2)
# Out:
# {'gang', 'lion', 'tiger'}

# %%
set2.intersection_update(set1)

# %%
print(set2)
# Out:
# {'lion', 'gang', 'tiger'}

# %%
set2.difference(set1)
# Out:
# {'rahul'}

# %% [markdown]
# ### Dictionaries

# %%
dic = {}

# %%
type(dic)
# Out:
# dict

# %%
y = dict()

# %%
type(y)
# Out:
# dict

# %%
set1 = {1,2,23 ,4,5}

# %%
type(set1)
# Out:
# set

# %%
dict1 = {'room1' : 'tony' , 'room2' :

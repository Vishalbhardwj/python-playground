# %%
# int
print('-------------')
print(3.14)
print(int(3.14))
print(int('10'))
print(int(False))
# Out:
# -------------
# 3.14
# 3
# 10
# 0

# %%
# float
print('-------------')
print(float(3))
print(float(True))
print(float('10.5'))
# Out:
# -------------
# 3.0
# 1.0
# 10.5

# %%
# str
print('-------------')
print(str(123))
print(str(123.23))
print(str(True))
# Out:
# -------------
# 123
# 123.23
# True

# %%
# bool
print('-------------')
print(bool(1))
print(bool(100000))
print(bool(-1211))
print(bool(0))
print(bool(0.0))
print(bool(423423.23))
print(bool('423947293'))
# Out:
# -------------
# True
# True
# True
# False
# False
# True
# True

# %%
print('-------------')
# Out:
# -------------

# %%
print(int(float('3.14')))
print(float(int(3.14)))
# Out:
# 3
# 3.0

# %%
print(type(float(int(3.14))))
print(type(23))
print(type(23.5))
print(type('23'))
print(type(True))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

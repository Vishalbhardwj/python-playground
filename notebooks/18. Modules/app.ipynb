# %%
from support import *

# %%
lst = [1,2,3,4,5]

# %%
print(greet('Ashish'))
print(subm(10,5))
print(arithmetic(10,5))
print(final(lst))
print(cu(lst))
print(sq(lst))
# Out:
# Hello Ashish
# 15
# (15, 5, 50)
# [2, 12, 36, 80, 150]
# [1, 8, 27, 64, 125]
# [1, 4, 9, 16, 25]
